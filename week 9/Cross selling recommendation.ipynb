# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from datetime import datetime, timedelta
from numpy import nan as NA

# %%
df = pd.read_csv('Test.csv',low_memory=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 929615 entries, 0 to 929614
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   fecha_dato             929615 non-null  object
#  1   ncodpers               929615 non-null  int64
#  2   ind_empleado           929615 non-null  object
#  3   pais_residencia        929615 non-null  object
#  4   sexo                   929610 non-null  object
#  5   age                    929615 non-null  int64
#  6   fecha_alta             929615 non-null  object
#  7   ind_nuevo              929615 non-null  int64
#  8   antiguedad             929615 non-null  int64
#  9   indrel                 929615 non-null  int64
#  10  ult_fec_cli_1t         1683 non-null    object
#  11  indrel_1mes            929592 non-null  float64
#  12  tiprel_1mes            929592 non-null  object
#  13  indresi                929615 non-null  object
# ...

# %%
pd.set_option('display.max_columns', None)
df.head(50)
# Out:
#     fecha_dato  ncodpers ind_empleado pais_residencia sexo  age  fecha_alta  \
# 0   2016-06-28     15889            F              ES    V   56  1995-01-16
# 1   2016-06-28   1170544            N              ES    H   36  2013-08-28
# 2   2016-06-28   1170545            N              ES    V   22  2013-08-28
# 3   2016-06-28   1170547            N              ES    H   22  2013-08-28
# 4   2016-06-28   1170548            N              ES    H   22  2013-08-28
# 5   2016-06-28   1170550            N              ES    V   22  2013-08-28
# 6   2016-06-28   1170552            N              ES    H   51  2013-08-28
# 7   2016-06-28   1170553            N              ES    H   22  2013-08-28
# 8   2016-06-28   1170555            N              ES    V   22  2013-08-28
# 9   2016-06-28   1170557            N              ES    H   22  2013-08-28
# 10  2016-06-28   1170559            N              ES    H   22  2013-08-28
# ...

# %% [markdown]
# # Data Cleaning

# %%
df.dropna(how='all',inplace=True)
df.dropna(axis=1, how='all', inplace=True)
df.drop_duplicates()
# Out:
#         fecha_dato  ncodpers ind_empleado pais_residencia sexo  age  \
# 0       2016-06-28     15889            F              ES    V   56
# 1       2016-06-28   1170544            N              ES    H   36
# 2       2016-06-28   1170545            N              ES    V   22
# 3       2016-06-28   1170547            N              ES    H   22
# 4       2016-06-28   1170548            N              ES    H   22
# ...            ...       ...          ...             ...  ...  ...
# 929610  2016-06-28    660237            N              ES    V   55
# 929611  2016-06-28    660238            N              ES    V   30
# 929612  2016-06-28    660240            N              ES    V   52
# 929613  2016-06-28    660243            N              ES    V   32
# 929614  2016-06-28    660248            N              ES    V   92
#
#         fecha_alta  ind_nuevo  antiguedad  indrel ult_fec_cli_1t  indrel_1mes  \
# ...

# %%
df.tail(50)
# Out:
#         fecha_dato  ncodpers ind_empleado pais_residencia sexo  age  \
# 929565  2016-06-28    660272            N              ES    H   48
# 929566  2016-06-28    660274            N              ES    H   46
# 929567  2016-06-28    660278            N              ES    H   43
# 929568  2016-06-28    660279            N              ES    H   71
# 929569  2016-06-28    660281            N              ES    H   79
# 929570  2016-06-28    660282            N              ES    H   11
# 929571  2016-06-28    660283            N              ES    H   31
# 929572  2016-06-28    660287            N              ES    V   58
# 929573  2016-06-28    660289            N              ES    V   33
# 929574  2016-06-28    660290            N              ES    V   77
# 929575  2016-06-28    660292            N              ES    V   33
# 929576  2016-06-28    660293            N              ES    H   40
# 929577  2016-06-28    660295            N              ES    V   31
# ...

# %%
df.iloc[2]['renta']
# Out:
# '         NA'

# %%
df['renta'].replace('         NA',np.nan,inplace=True)

# %%
df['renta'].isna().sum()
# Out:
# 227965

# %%
df['renta'] = df['renta'].astype(float, errors = 'raise')

# %%
df['renta'].mean(skipna=True)
# Out:
# 134087.8705946269

# %%
df['renta'].median(skipna=True)
# Out:
# 101490.51000000001

# %%
df['renta'].describe()
# Out:
# count    7.016500e+05
# mean     1.340879e+05
# std      2.323120e+05
# min      1.202730e+03
# 25%      6.849114e+04
# 50%      1.014905e+05
# 75%      1.555408e+05
# max      2.889440e+07
# Name: renta, dtype: float64

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(10,6))
sns.boxplot(df.renta)
# Out:
# C:\Users\liaoj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='renta'>

# %%
df['renta'].replace(np.nan,df['renta'].mean(skipna=True),inplace=True)
df['renta'].describe()
# Out:
# count    9.296150e+05
# mean     1.340879e+05
# std      2.018274e+05
# min      1.202730e+03
# 25%      7.829529e+04
# 50%      1.314846e+05
# 75%      1.340879e+05
# max      2.889440e+07
# Name: renta, dtype: float64

# %%
df['renta'].describe()
# Out:
# count    9.296150e+05
# mean     1.340879e+05
# std      2.018274e+05
# min      1.202730e+03
# 25%      7.829529e+04
# 50%      1.314846e+05
# 75%      1.340879e+05
# max      2.889440e+07
# Name: renta, dtype: float64

# %%
df['renta'].quantile(0.75)
# Out:
# 134087.8705946269

# %%
outliers = df['renta'].quantile(0.75) + 1.5 * (df['renta'].quantile(0.75) - df['renta'].quantile(0.25))
outliers
# Out:
# 217776.74148656725

# %%
strong_outliers = df['renta'].quantile(0.75) + 3 * (df['renta'].quantile(0.75) - df['renta'].quantile(0.25))
strong_outliers
# Out:
# 301465.6123785076

# %%
i = df[df['renta']== df['renta'].max()].index
df.drop(i)
# Out:
#         fecha_dato  ncodpers ind_empleado pais_residencia sexo  age  \
# 0       2016-06-28     15889            F              ES    V   56
# 1       2016-06-28   1170544            N              ES    H   36
# 2       2016-06-28   1170545            N              ES    V   22
# 3       2016-06-28   1170547            N              ES    H   22
# 4       2016-06-28   1170548            N              ES    H   22
# ...            ...       ...          ...             ...  ...  ...
# 929610  2016-06-28    660237            N              ES    V   55
# 929611  2016-06-28    660238            N              ES    V   30
# 929612  2016-06-28    660240            N              ES    V   52
# 929613  2016-06-28    660243            N              ES    V   32
# 929614  2016-06-28    660248            N              ES    V   92
#
#         fecha_alta  ind_nuevo  antiguedad  indrel ult_fec_cli_1t  indrel_1mes  \
# ...

# %%
df['antiguedad'].replace(-999999,np.nan, inplace=True)

# %%
df['antiguedad'].describe()
# Out:
# count    929612.000000
# mean         80.955814
# std          67.241802
# min           0.000000
# 25%          23.000000
# 50%          55.000000
# 75%         136.000000
# max         257.000000
# Name: antiguedad, dtype: float64

# %%
df['antiguedad'].isna().values.any()
# Out:
# True

# %%
outliers = 136 + 1.5 * (136 - 23)
outliers > df['antiguedad'].max()
# Out:
# True

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(10,6))
sns.boxplot(df.antiguedad)
# Out:
# C:\Users\liaoj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='antiguedad'>
